# %%
from twin.paper_figures import *

# %%
fig = tree_of_cliques()

# %%
fig = tree_of_cliques_curves(curvature=0.5)

# %%
fig = tree_of_cliques_curves(curvature=1.0)

# %%
fig = small_world()

# %%
fig = small_world_curves(curvature=0.5)

# %%
fig = small_world_curves(curvature=1.0)

# %%
fig = football_figure()

# %%
fig = football_curves(curvature=0.5)

# %%
fig = football_curves(curvature=1.0)

# %%
fig = tabula_sapiens_teaser()
