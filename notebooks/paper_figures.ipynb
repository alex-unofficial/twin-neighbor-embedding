# %%
from twin.paper_figures import *
# Out:
# 2026-01-23 22:04:28.016 | INFO     | twin.config:<module>:11 - PROJ_ROOT path is: /home/alex/Projects/twin

# %%
fig = tree_of_cliques()
# Out:
# 2026-01-23 22:04:29.967 | INFO     | twin.paper_figures:tree_of_cliques:248 - Creating Tree of Cliques figure
# 2026-01-23 22:04:30.432 | SUCCESS  | twin.paper_figures:tree_of_cliques:270 - Generated embeddings in 0.45555522500035295 seconds
# 2026-01-23 22:04:30.727 | INFO     | twin.paper_figures:tree_of_cliques:287 - Creating Tree of Cliques plots...

# %%
fig = tree_of_cliques_curves()
# Out:
# 2026-01-23 22:04:31.569 | INFO     | twin.paper_figures:tree_of_cliques_curves:364 - Creating Tree of Cliques curves figure

# %%
fig = small_world()
# Out:
# 2026-01-23 22:04:32.381 | INFO     | twin.paper_figures:small_world:423 - Creating Small World figure
# 2026-01-23 22:04:40.640 | SUCCESS  | twin.paper_figures:small_world:445 - Generated embeddings in 8.255171756999516 seconds
# 2026-01-23 22:04:40.641 | INFO     | twin.paper_figures:small_world:453 - Creating Small World plots...

# %%
fig = small_world_curves()
# Out:
# 2026-01-23 22:04:40.908 | INFO     | twin.paper_figures:small_world_curves:487 - Creating Small World curves figure

# %%
fig = football_figure()
# Out:
# 2026-01-23 22:04:51.402 | INFO     | twin.paper_figures:football_figure:536 - Creating Football figure
# /home/alex/Projects/twin/venv/lib/python3.14/site-packages/scipy/io/matlab/_mio.py:236: MatReadWarning: Duplicate variable name "None" in stream - replacing previous with new
# Considerscipy.io.matlab.varmats_from_mat to split file into single variable files
#   matfile_dict = MR.get_variables(variable_names)
# 2026-01-23 22:05:02.134 | SUCCESS  | twin.paper_figures:football_figure:558 - Generated embeddings in 10.725819061999573 seconds
# 2026-01-23 22:05:02.137 | INFO     | twin.paper_figures:football_figure:643 - Creating Football plots...

# %%
fig = football_curves()
# Out:
# 2026-01-23 22:05:02.575 | INFO     | twin.paper_figures:football_curves:680 - Creating Football curves figure
# /home/alex/Projects/twin/venv/lib/python3.14/site-packages/scipy/io/matlab/_mio.py:236: MatReadWarning: Duplicate variable name "None" in stream - replacing previous with new
# Considerscipy.io.matlab.varmats_from_mat to split file into single variable files
#   matfile_dict = MR.get_variables(variable_names)

# %%
fig = tabula_sapiens_teaser()
# Out:
# 2026-01-23 22:05:15.605 | INFO     | twin.paper_figures:tabula_sapiens_teaser:105 - Creating Tabula Liver figure
# 2026-01-23 22:07:11.563 | SUCCESS  | twin.paper_figures:tabula_sapiens_teaser:131 - Generated embeddings in 115.55744377999963 seconds
# 2026-01-23 22:07:23.215 | INFO     | twin.paper_figures:tabula_sapiens_teaser:199 - Creating Tabula plots..
