# %%
from twin.paper_figures import *
# Out:
# 2025-02-26 18:37:01.543 | INFO     | twin.config:<module>:11 - PROJ_ROOT path is: /home/alex/Projects/twin

# %%
fig = tree_of_cliques()
# Out:
# 2025-02-26 18:37:03.368 | INFO     | twin.paper_figures:tree_of_cliques:436 - Creating Tree of Cliques figure
# 2025-02-26 18:37:03.795 | SUCCESS  | twin.paper_figures:tree_of_cliques:458 - Generated embeddings in 0.4174244810001255 seconds
# 2025-02-26 18:37:04.145 | INFO     | twin.paper_figures:tree_of_cliques:475 - Creating Tree of Cliques plots...

# %%
fig = small_world()
# Out:
# 2025-02-26 18:37:05.005 | INFO     | twin.paper_figures:small_world:552 - Creating Small World figure
# 2025-02-26 18:37:13.172 | SUCCESS  | twin.paper_figures:small_world:574 - Generated embeddings in 8.16187969800012 seconds
# 2025-02-26 18:37:13.173 | INFO     | twin.paper_figures:small_world:582 - Creating Small World plots...

# %%
fig = football_figure()
# Out:
# 2025-02-26 18:37:13.408 | INFO     | twin.paper_figures:football_figure:613 - Creating Football figure
# /home/alex/Projects/twin/venv/lib/python3.13/site-packages/scipy/io/matlab/_mio.py:235: MatReadWarning: Duplicate variable name "None" in stream - replacing previous with new
# Considerscipy.io.matlab.varmats_from_mat to split file into single variable files
#   matfile_dict = MR.get_variables(variable_names)
# 2025-02-26 18:37:24.674 | SUCCESS  | twin.paper_figures:football_figure:635 - Generated embeddings in 11.258254705000581 seconds
# 2025-02-26 18:37:24.676 | INFO     | twin.paper_figures:football_figure:720 - Creating Football plots...

# %%
fig = tabula_sapiens_teaser()
# Out:
# 2025-02-26 18:37:25.008 | INFO     | twin.paper_figures:tabula_sapiens_teaser:109 - Creating Tabula Liver figure
# 2025-02-26 18:39:13.763 | SUCCESS  | twin.paper_figures:tabula_sapiens_teaser:135 - Generated embeddings in 108.28882774200065 seconds
# 2025-02-26 18:39:25.065 | INFO     | twin.paper_figures:tabula_sapiens_teaser:203 - Creating Tabula plots..
